# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/Predict_customer_Will_Leave_the-Bank/master/BankCustomers.csv')
dataset.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
# dataset.drop('Gender_num', axis=1,inplace=True)

# %%
# dataset['Geography']=dataset['Geography'].astype('category')
# dataset['Gender']= dataset['Gender'].astype('category')

# %%
# dataset['Countries']= dataset['Geography'].cat.codes
# dataset['Gndr'] = dataset['Gender'].cat.codes

# %%
# dataset.columns

# %%
# dataset.drop(['Gender', 'Geography'], axis=1, inplace=True)

# %%
dataset.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
# Converting Categorical variables into numerical values

# states= pd.get_dummies(X['Geography'], drop_first=True)
# gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
# dataset['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
# using series method to map categorical features

dataset['Geo'] = dataset['Geography'].map({'France': 0,'Germany':1,'Spain':2})
dataset['Sex'] = dataset['Gender'].map({'Female':0,'Male':1})

# %%
dataset.drop(['Geography','Gender'],axis=1,inplace=True)

# %%
dataset.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
# 5          6    15574012       Chu          645   44       8  113755.78
# 6          7    15592531  Bartlett          822   50       7       0.00
# 7          8    15656148    Obinna          376   29       4  115046.74
# 8          9    15792365        He          501   44       4  142051.07
# 9         10    15592389        H?          684   27       2  134603.88
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geo  Sex
# 0              1          1               1        101348.88       1    0    0
# ...

# %%
X = dataset.iloc[:,[3,4,5,6,7,8,9,10,12,13]].values
y = dataset.iloc[:, 11].values

# %%
# states=pd.get_dummies(dataset['Geography'], drop_first=True)

# %%
# sex = pd.get_dummies(dataset['Gender'],drop_first=True)

# %%
# X = pd.concat([X,states,sex],axis=1)

# %%
# Splitting the data into train and test dataset

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN

classifier = Sequential()

# Adding input layer and first hidden layer

classifier.add(Dense(input_dim=10,units=6,kernel_initializer='uniform',activation = 'relu'))


# Adding the Second hidden layer

classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu',))

# Adding the Output layer

classifier.add(Dense(activation='sigmoid',units=1,kernel_initializer='uniform'))

# Compiling the ANN

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics =['accuracy'])

# Fitting the ANN to the training set

classifier.fit(X_train,y_train,batch_size=10,epochs=15)
# Out:
# Epoch 1/15
# 8000/8000 [==============================] - 2s 284us/step - loss: 0.4859 - accuracy: 0.7983
# Epoch 2/15
# 8000/8000 [==============================] - 2s 276us/step - loss: 0.4343 - accuracy: 0.7983
# Epoch 3/15
# 8000/8000 [==============================] - 2s 243us/step - loss: 0.4299 - accuracy: 0.7983
# Epoch 4/15
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.4253 - accuracy: 0.8131
# Epoch 5/15
# 8000/8000 [==============================] - 2s 258us/step - loss: 0.4226 - accuracy: 0.8273
# Epoch 6/15
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.4204 - accuracy: 0.8306
# Epoch 7/15
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.4194 - accuracy: 0.8313
# Epoch 8/15
# 8000/8000 [==============================] - 2s 280us/step - loss: 0.4179 - accuracy: 0.8325
# Epoch 9/15
# 8000/8000 [==============================] - 2s 240us/step - loss: 0.4167 - accuracy: 0.8328
# Epoch 10/15
# ...

# %%
# predicting the test set results

y_pred = classifier.predict(X_test)
y_pred = (y_pred>0.5)

# %%
# Making confusion matrix

from sklearn.metrics import confusion_matrix,accuracy_score

cm = confusion_matrix(y_test,y_pred)
accuracy = accuracy_score(y_test,y_pred)

# %%
print(cm)
print("The accuracy for the model is {0:.2f} %".format(accuracy*100))
# Out:
# [[1541   36]
#  [ 297  126]]
# The accuracy for the model is 83.35 %
